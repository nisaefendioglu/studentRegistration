# %%
name = 'nisa'
surname = 'efendioglu'
lessons = ["1.Chemistry", "2.Maths", "3.Science", "4.Biology", "5.Art"]
Chemistry = [38,66,89]
Maths = [48,55,72]
Science = [10,20,30]
Biology = [48, 52,65]
Art = [23,5,19]
for i in range(3):
    name1 = input('Your Name:')
    surname1 = input('Your Surname:')
    if not name1 or not surname1:
        print("This field cannot be left blank!")   
    elif i == 3:
            print("Please try again later!")
            break
    elif name1 != name and surname1 != surname:
        print("Incorrect entry. Try Again!")
    elif name1 == name and surname1 == surname:
        print("Welcome" , name1, surname1, end="!\n")
        print("Lessons you can take:", lessons)
        print("Select a lessons *This student can take a minimum of 3 and a maximum of 5 lessons*")
        id1=input("Enter the ID number of the course you want to choose:")
        id2=input("Enter the ID number of the course you want to choose:")
        id3=input("Enter the ID number of the course you want to choose:")
        selection = input("Would you like to choose another course? Y/N:")
        if selection == "y" or selection == "Y":
            id4=input("Enter the ID number of the course you want to choose:")
            selection = input("Would you like to choose another course? Y/N:")
            if selection == "y" or selection == "Y":
                id5=input("Enter the ID number of the course you want to choose:")
            elif selection =="n" or selection =="N":
                continue
        else:
            if id1 == "1" or id2=="1" or id3=="1" or id4=="1" or id5=="1":
                midterm = Chemistry[0]
                final = Chemistry[1]
                project = Chemistry[2]
                result = midterm*30/100 +final*50/100 +project*20/100
                print("Chemistry Lesson Average:" , result)
                if result>= 90:
                    print("AA")
                elif result >= 70 and result <= 90:
                    print("BB")
                elif result >= 50 and result <=70:
                    print("CC")
                elif result >=30 and result <=50:
                    print("DD")
                elif result <30:
                    print("FF You failed in class")
            if id1 == "2" or id2=="2" or id3=="2" or id4=="2" or id5=="2":
                midterm = Maths[0]
                final = Maths[1]
                project = Maths[2]
                result = midterm*30/100 +final*50/100 +project*20/100
                print("Maths Lesson Average:" , result)
                if result>= 90:
                    print("AA")
                elif result >= 70 and result <= 90:
                    print("BB")
                elif result >= 50 and result <=70:
                    print("CC")
                elif result >=30 and result <=50:
                    print("DD")
                elif result <30:
                    print("FF You failed in class")
            if id1 == "3" or id2=="3" or id3=="3" or id4=="3" or id5=="3":
                midterm = Science[0]
                final = Science[1]
                project = Science[2]
                result = midterm*30/100 +final*50/100 +project*20/100
                print("Science Lesson Average:" , result)
                if result>= 90:
                    print("AA")
                elif result >= 70 and result <= 90:
                    print("BB")
                elif result >= 50 and result <=70:
                    print("CC")
                elif result >=30 and result <=50:
                    print("DD")
                elif result <30:
                    print("FF You failed in class")
            if id1 == "4" or id2=="4" or id3=="4" or id4=="4" or id5=="4":
                midterm = Biology[0]
                final = Biology[1]
                project = Biology[2]
                result = midterm*30/100 +final*50/100 +project*20/100
                print("Biology Lesson Average:" , result)
                if result>= 90:
                    print("AA")
                elif result >= 70 and result <= 90:
                    print("BB")
                elif result >= 50 and result <=70:
                    print("CC")
                elif result >=30 and result <=50:
                    print("DD")
                elif result <30:
                    print("FF You failed in class")
            if id1 == "5" or id2=="5" or id3=="5" or id4=="5" or id5=="5":
                midterm = Art[0]
                final = Art[1]
                project = Art[2]
                result = midterm*30/100 +final*50/100 +project*20/100
                print("Art Lesson Average:" , result)
                if result>= 90:
                    print("AA")
                elif result >= 70 and result <= 90:
                    print("BB")
                elif result >= 50 and result <=70:
                    print("CC")
                elif result >=30 and result <=50:
                    print("DD")
                elif result <30:
                    print("FF You failed in class")
# Out:
# Your Name:nisa
# Your Surname:efendioglu
# Welcome nisa efendioglu!
# Lessons you can take: ['1.Chemistry', '2.Maths', '3.Science', '4.Biology', '5.Art']
# Select a lessons *This student can take a minimum of 3 and a maximum of 5 lessons*
# Enter the ID number of the course you want to choose:3
# Enter the ID number of the course you want to choose:4
# Enter the ID number of the course you want to choose:5
# Would you like to choose another course? Y/N:N
# Science Lesson Average: 19.0
# FF You failed in class
# Biology Lesson Average: 53.4
# CC
# Art Lesson Average: 13.2
# FF You failed in class
